# %% [markdown]
# # Tidy Data

# %% [markdown]
# The aim of this Capstone project is to consolidate the knowledge, skills and competences acquired by learners during this programme. In this project students will select, specify, design, justify and implement a data analytics investigation that makes use of large data sets. The project will necessarily require data ingestion, wrangling, computation and analyses, and the production and presentation of a project and report. Students are guided by faculty in the selection of a data set, scope of investigation, initial exploratory data analysis, and formulation of hypotheses.

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import ast
import re

# %%
deck_df = pd.read_csv("data/winning_decks.csv")

# %%
card_df = pd.read_csv("data/cards.csv")

# %% [markdown]
# There are 6 houses in total: Brobnar, Dis, Sanctum, Mars, Untamed, Shadows, Logos. We want to add those 6 columns and a boolean True of False for whether the deck has that house or not.

# %%
deck_df['house_brobnar'] = deck_df['houses'].str.contains('Brobnar')
deck_df['house_dis'] = deck_df['houses'].str.contains('Dis')
deck_df['house_sanctum'] = deck_df['houses'].str.contains('Sanctum')
deck_df['house_mars'] = deck_df['houses'].str.contains('Mars')
deck_df['house_untamed'] = deck_df['houses'].str.contains('Untamed')
deck_df['house_shadows'] = deck_df['houses'].str.contains('Shadows')
deck_df['house_logos'] = deck_df['houses'].str.contains('Logos')

# %%
deck_df = deck_df.drop("houses", axis=1)
deck_df.drop(deck_df.columns[deck_df.columns.str.contains('Unnamed',case = False)],axis = 1, inplace = True)

# %%
deck_df.head()
# Out:
#                                 deck_id  \
# 0  6216e565-a790-4e5b-b89a-4a814917b94e
# 1  50e28cdd-6e6b-4584-a8d1-1f22c081e906
# 2  3969e139-05d7-4a8a-ba60-0bb660cd057b
# 3  5668bdc3-dea4-4226-92ba-91b003a5460e
# 4  749780f6-7acb-402a-9fd6-f6fbbcf888e1
#
#                                   deck_name  deck_wins  deck_losses  \
# 0    Leif “As”, Granjera de la Alcantarilla          2            1
# 1           “Ivan” Valencia, Ship Chieftain          1            3
# 2                  Nasir, Canal Survivalist          2            1
# 3           Destrolack, Observatory Recluse          4            4
# 4  Tiberius, Navigatore della Guglia Aperta          8            4
#
#    deck_expansion                                          deck_list  \
# 0             435  ['417b7845-2c67-4bcf-b411-20f2a7d86955', '920f...
# 1             435  ['2ee769bb-b785-48ea-a5fa-a19a2af32bbc', '2ee7...
# 2             435  ['a3234c40-8226-439d-bb8f-207ea26c9560', '920f...
# 3             435  ['7bf05cd5-7c03-4e06-9ace-bb730ff6100e', '7bf0...
# 4             341  ['753bfb51-4ba7-4c0a-b141-a5b6388498c0', 'aeed...
#
#    house_brobnar  house_dis  house_sanctum  house_mars  house_untamed  \
# 0           True       True           True       False          False
# 1           True      False           True       False           True
# 2           True      False           True        True          False
# 3          False      False           True       False           True
# 4          False      False          False        True           True
#
#    house_shadows  house_logos
# 0          False        False
# 1          False        False
# 2          False        False
# 3          False         True
# 4           True        False

# %% [markdown]
# Next we need to look at the cards.

# %%
card_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                               card_id  \
# 0           0             0  bfaef0df-911c-4f21-a452-83d1144dc0c4
# 1           1             1  e3a8d05a-252a-4d07-bebe-8a5b69efb98c
# 2           2             2  98e9c095-d134-4bed-b6db-4bfacb433473
# 3           3             3  30dfd43a-4973-482a-8a52-be37d8cf0ca8
# 4           4             4  38b9c734-5286-4c94-b92a-28e3aa4f1357
#
#           card_title card_type  card_amber  card_power  card_armor  \
# 0  Ixxyxli Fixfinger  Creature           0         2.0         2.0
# 1       Yantzee Gang  Creature           0         5.0         NaN
# 2  Scientifical Hack  Artifact           1         NaN         NaN
# 3      Cull the Weak    Action           1         NaN         NaN
# 4          Oubliette    Action           0         NaN         NaN
#
#            card_traits
# 0  Martian • Scientist
# 1          Elf • Thief
# 2             Equation
# 3                  NaN
# 4                  NaN

# %% [markdown]
# For some cards they only appear once.

# %%
card_df.loc[card_df['card_title']=='Ixxyxli Fixfinger']
# Out:
#    Unnamed: 0  Unnamed: 0.1                               card_id  \
# 0           0             0  bfaef0df-911c-4f21-a452-83d1144dc0c4
#
#           card_title card_type  card_amber  card_power  card_armor  \
# 0  Ixxyxli Fixfinger  Creature           0         2.0         2.0
#
#            card_traits
# 0  Martian • Scientist

# %% [markdown]
# Other cards however appear under multiple card_ids, this is because they have special versions that appear in other houses. So if we look at the card 'Bait and Switch' we can see it appears a total of 7 times, one for each house.

# %%
card_df.loc[card_df['card_title']=='Bait and Switch']
# Out:
#       Unnamed: 0  Unnamed: 0.1                               card_id  \
# 448          797           182  0186f94c-68df-4d5c-9338-9e918affe313
# 1005       95391            13  771eb74c-d367-46af-be2f-994cd78f0e8e
# 1313      248243           286  a20770c0-dea0-4690-8ef6-c93e64105229
# 2015       47598           171  771c498c-33bc-40b7-8d41-54fd0a7c2567
# 2116      102887           211  0cf698fb-1d7d-4ecb-804a-fa7904501945
# 2191      144447            22  ef9a58d8-9684-4f39-9a1d-cc93a04d0027
# 2300      228373            60  bf82eb92-cfae-4b59-b676-f8f3013e4572
#
#            card_title card_type  card_amber  card_power  card_armor  \
# 448   Bait and Switch    Action           0         0.0         0.0
# 1005  Bait and Switch    Action           0         0.0         0.0
# 1313  Bait and Switch    Action           0         0.0         0.0
# 2015  Bait and Switch    Action           0         0.0         0.0
# 2116  Bait and Switch    Action           0         0.0         0.0
# 2191  Bait and Switch    Action           0         0.0         0.0
# 2300  Bait and Switch    Action           0         0.0         0.0
#
#      card_traits
# 448          NaN
# 1005         NaN
# 1313         NaN
# 2015         NaN
# 2116         NaN
# 2191         NaN
# 2300         NaN

# %% [markdown]
# If we want to add a boolean value for each card, we a column for each of the unique cards name which are a total of:

# %%
len(card_df.groupby('card_title')['card_title'].nunique())
# Out:
# 574

# %% [markdown]
# So we need to add 574 columns. Lets start by getting the list of names.

# %%
series_of_cards = card_df['card_title']
list_of_cards = list(dict.fromkeys(series_of_cards))
list_of_cards.sort()
list_of_cards
# Out:
# ['1-2 Punch',
#  'A Fair Game',
#  'Abond the Armorsmith',
#  'Agent Hoo-man',
#  'Ammonia Clouds',
#  'Anahita the Trader',
#  'Ancient Bear',
#  'Ancient Yurk',
#  'Anger',
#  'Angwish',
#  'Annihilation Ritual ',
#  'Anomaly Exploiter',
#  'Archimedes',
#  'Arise!',
#  'Armageddon Cloak',
#  'Aubade the Grim',
#  'Autocannon',
#  'Backup Copy',
#  'Bad Penny',
#  'Bait and Switch',
#  'Banish',
#  'Banner of Battle',
#  'Barehanded',
#  'Baron Mengevin',
#  'Barrister Joya',
#  'Batdrone',
#  'Battle Fleet',
#  'Bear Flute',
#  'Begone!',
#  'Bellowing Patrizate',
#  'Bigtwig',
#  'Bilgum Avalanche',
#  'Binate Rupture',
#  'Binding Irons',
#  'Bingle Bangbang',
#  'Biomatrix Backup',
#  'Blinding Light',
#  'Blood Money',
#  'Blood of Titans',
#  'Bloodshard Imp',
#  'Blypyp',
#  'Bonerot Venom',
#  'Booby Trap',
#  'Bordan the Redeemed',
#  'Bouncing Deathquark',
#  'Brain Eater',
#  'Brain Stem Antenna',
#  'Brammo',
#  'Brend the Fanatic',
#  'Briar Grubbling',
#  'Brobnar Ambassador',
#  'Bronze Key Imp',
#  'Brothers in Battle',
#  'Bulleteye',
#  'Bulwark',
#  'Bumblebird',
#  'Bumpsy',
#  'Burn the Stockpile',
#  'Camouflage',
#  'Cannon',
#  'Carlo Phantom',
#  'Carpet Phloxem',
#  'Challe the Safeguard',
#  'Champion Anaphiel',
#  'Champion Tabris',
#  'Champion’s Challenge',
#  'Chaos Portal',
#  'Charette',
#  'Charge!',
#  'Chota Hazri',
#  'Chuff Ape',
#  'Cleansing Wave',
#  'Clear Mind',
#  'Collar of Subordination',
#  'Collector Worm',
#  'Combat Pheromones',
#  'Commander Remiel',
#  'Commpod',
#  'Containment Field',
#  'Control the Weak',
#  'Cooperative Hunting',
#  'Coward’s End',
#  'Cowfyne',
#  'Crazy Killing Machine',
#  'Creeping Oblivion',
#  'Crystal Hive',
#  'Culf the Quiet',
#  'Cull the Weak',
#  'Curiosity',
#  'Custom Virus',
#  'Customs Office',
#  'Cutthroat Research',
#  'Cybergiant Rig',
#  'Dance of Doom',
#  'Deep Probe',
#  'Deipno Spymaster',
#  'Destroy Them All!',
#  'Destructive Analysis',
#  'Dew Faerie',
#  'Dextre',
#  'Dharna',
#  'Dimension Door',
#  'Director of Z.Y.X.',
#  'Dis Ambassador',
#  'Doc Bookton',
#  'Dodger',
#  'Dominator Bauble',
#  'Doorstep to Heaven',
#  'Dr. Escotera',
#  'Drumble',
#  'Drummernaut',
#  'Duma the Martyr',
#  'Dusk Chronicles',
#  'Duskrunner',
#  'Duskwitch',
#  'Dust Imp',
#  'Dust Pixie',
#  'Dysania',
#  'EMP Blast',
#  'Earthbind',
#  'Earthshaker',
#  'Eater of the Dead',
#  'Effervescent Principle',
#  'Ember Imp',
#  'Entropic Manipulator',
#  'Entropic Swirl',
#  'Epic Quest',
#  'Equalize',
#  'Ether Spider',
#  'Eureka!',
#  'Evasion Sigil',
#  'Exhume',
#  'Experimental Therapy',
#  'Exterminate! Exterminate!',
#  'Extinction',
#  'Eye of Judgment',
#  'Eyegor',
#  'Fanghouse',
#  'Faygin',
#  'Fear',
#  'Feeding Pit',
#  'Fertility Chant',
#  'Fetchdrones',
#  'Fila the Researcher',
#  'Finishing Blow',
#  'Firespitter',
#  'First Blood',
#  'Flame-Wreathed',
#  'Flamethrower',
#  'Flamewake Shaman',
#  'Flaxia',
#  'Fogbank',
#  'Foggify',
#  'Follow the Leader',
#  'Foozle',
#  'Forgemaster Og',
#  'Francus',
#  'Free Markets',
#  'Full Moon',
#  'Furtive Investors',
#  'Fuzzy Gruen',
#  'Gabos Longarms',
#  'Gamgee',
#  'Ganger Chieftain',
#  'Ganymede Archivist',
#  'Gargantes Scrapper',
#  'Gatekeeper',
#  'Gateway to Dis',
#  'Gauntlet of Command',
#  'Ghostly Hand',
#  'Giant Sloth',
#  'Glimmer',
#  'Glorious Few',
#  'Glyxl Proliferator',
#  'Gold Key Imp',
#  'Golden Aura',
#  'Gongoozle',
#  'Gorm of Omm',
#  'Grabber Jammer',
#  'Grasping Vines',
#  'Gravid Cycle',
#  'Grenade Snib',
#  'Grey Monk',
#  'Groggins',
#  'Groke',
#  'Grommid',
#  'Grovekeeper',
#  'Grump Buggy',
#  'Grumpus Tamer',
#  'Guard Disguise',
#  'Guardian Demon',
#  'Gub',
#  'Guilty Hearts',
#  'Haedroth’s Wall',
#  'Halacor',
#  'Hallowed Blaster',
#  'Hallowed Shield',
#  'Hand of Dis',
#  'Harland Mindlock',
#  'Hayyel the Merchant',
#  'Headhunter',
#  'Healing Blast',
#  'Heart of the Forest',
#  'Hebe the Huge',
#  'Hecatomb',
#  'Heist Night',
#  'Help from Future Self',
#  'Helper Bot',
#  'Hexpion',
#  'Hidden Stash',
#  'Hideaway Hole',
#  'Honorable Claim',
#  'Horseman of Death',
#  'Horseman of Famine',
#  'Horseman of Pestilence',
#  'Horseman of War',
#  'Hunting Witch',
#  'Hypnobeam',
#  'Hypnotic Command',
#  'Hysteria',
#  'Imperial Traitor',
#  'Incubation Chamber',
#  'Inka the Spider',
#  'Inspiration',
#  'Interdimensional Graft',
#  'Into the Fray',
#  'Invasion Portal',
#  'Iron Obelisk',
#  'Irradiated Æmber',
#  'Ixxyxli Fixfinger',
#  'Jammer Pack',
#  'Jargogle',
#  'Jehu the Bureaucrat',
#  'Kelifi Dragon',
#  'Key Abduction',
#  'Key Charge',
#  'Key Hammer',
#  'Key of Darkness',
#  'Key to Dis',
#  'Killzord mk. 9001',
#  'Kindrith Longshot',
#  'King of the Crag',
#  'Knowledge is Power',
#  'Knoxx',
#  'Knuckles Bolton',
#  'Krump',
#  'Labwork',
#  'Lady Maxena',
#  'Lamindra',
#  'Lash of Broken Dreams',
#  'Lava Ball',
#  'Lethal Distraction',
#  'Library Access',
#  'Library of Babble',
#  'Library of the Damned',
#  'Life for a Life',
#  'Lifeward',
#  'Lifeweb',
#  'Lights Out',
#  'Little Niff',
#  'Little Rapscal',
#  'Logos Ambassador',
#  'Lollop the Titanic',
#  'Lomir Flamefist',
#  'Longfused Mines',
#  'Loot the Bodies',
#  'Looter Goblin',
#  'Lord Golgotha',
#  'Lost in the Woods',
#  'Lupo the Scarred',
#  'Macis Asp',
#  'Mack the Knife',
#  'Magda the Rat',
#  'Mantle of the Zealot',
#  'Marmo Swarm',
#  'Mars Ambassador',
#  'Mars First',
#  'Mars Needs Æmber',
#  'Martian Generosity',
#  'Martian Hounds',
#  'Martians Make Bad Allies',
#  'Martyr’s End',
#  'Maruck the Marked',
#  'Mass Abduction',
#  'Master of 1',
#  'Master of 2',
#  'Master of 3',
#  'Master the Theory',
#  'Masterplan',
#  'Mating Season',
#  'Memory Chip',
#  'Miasma',
#  'Might Makes Right',
#  'Mighty Javelin',
#  'Mighty Lance',
#  'Mighty Tiger',
#  'Mimicry',
#  'Mind Barb',
#  'Mindwarper',
#  'Mindworm',
#  'Misery Exploit',
#  'Mobius Scroll',
#  'Mooncurser',
#  'Mother',
#  'Mother Northelle',
#  'Mothergun',
#  'Mothership Support',
#  'Mugwump',
#  'Murkens',
#  'Murmook',
#  'Mushroom Man',
#  'Nature’s Call',
#  'Neffru',
#  'Nepenthe Seed',
#  'Nerve Blast',
#  'Neuro Syphon',
#  'Neutron Shark',
#  'Nexus',
#  'Niffle Ape',
#  'Niffle Grounds',
#  'Niffle Queen',
#  'Nightforge',
#  'Nocturnal Maneuver',
#  'Noddy the Thief',
#  'Not Finished with You',
#  'Novu Archaeologist',
#  'Numquid the Fair',
#  'Nyzyk Resonator',
#  'Oath of Poverty',
#  'Ogopogo',
#  'Old Bruno',
#  'Old Yurk',
#  'One Last Job',
#  'One Stood Against Many',
#  'Onyx Knight',
#  'Opal Knight',
#  'Orb of Invidius',
#  'Orbital Bombardment',
#  'Ortannu the Chained',
#  'Ortannu’s Binding',
#  'Oubliette',
#  'Overlord Greking',
#  'Ozmo, Martianologist',
#  'Pain Reaction',
#  'Pandemonium',
#  'Panpaca, Anga',
#  'Panpaca, Jaga',
#  'Pawn Sacrifice',
#  'Perilous Wild',
#  'Perplexing Sophistry',
#  'Persistence Hunting',
#  'Phase Shift',
#  'Phloxem Spike',
#  'Phoenix Heart',
#  'Phosphorus Stars',
#  'Phylyx the Disintegrator',
#  'Pile of Skulls',
#  'Pingle Who Annoys',
#  'Pip Pip',
#  'Piranha Monkeys',
#  'Pit Demon',
#  'Pitlord',
#  'Plague Rat',
#  'Pocket Universe',
#  'Poison Wave',
#  'Poke',
#  'Poltergeist',
#  'Positron Bolt',
#  'Potion of Invulnerability',
#  'Pound',
#  'Po’s Pixies',
#  'Prince Derric, Unifier',
#  'Proclamation 346E',
#  'Professor Sutterkin',
#  'Project Z.Y.X.',
#  'Protect the Weak',
#  'Protectrix',
#  'Psychic Bug',
#  'Psychic Network',
#  'Punch',
#  'Punctuated Equilibrium',
#  'Quantum Fingertrap',
#  'Quicksand',
#  'Quixo the “Adventurer”',
#  'Qyxxlyx Plague Master',
#  'Radiant Truth',
#  'Raiding Knight',
#  'Random Access Archives',
#  'Red Planet Ray Gun',
#  'Red-Hot Armor',
#  'Redlock',
#  'Regrowth',
#  'Relentless Assault',
#  'Relentless Whispers',
#  'Remote Access',
#  'Replicator',
#  'Research Smoko',
#  'Restringuntus',
#  'Reverse Time',
#  'Rigged Lottery',
#  'Ring of Invisibility',
#  'Ritual of Balance',
#  'Ritual of the Hunt',
#  'Rock-Hurling Giant',
#  'Rocket Boots',
#  'Rogue Ogre',
#  'Ronnie Wristclocks',
#  'Rothais the Fierce',
#  'Round Table',
#  'Routine Job',
#  'Roxador',
#  'Rustgnawer',
#  'Sack of Coins',
#  'Sacrificial Altar',
#  'Safe Place',
#  'Sample Collection',
#  'Sanctum Guardian',
#  'Save the Pack',
#  'Scientifical Hack',
#  'Scout',
#  'Scowly Caper',
#  'Scrambler Storm',
#  'Screaming Cave',
#  'Screechbomb',
#  'Seeker Needle',
#  'Seismo-entangler',
#  'Selwyn the Fence',
#  'Sequis',
#  'Seraphic Armor',
#  'Sergeant Zakiel',
#  'Shadow Self',
#  'Shadow of Dis',
#  'Shadows Ambassador',
#  'Shaffles',
#  'Shard of Greed',
#  'Shard of Hate',
#  'Shard of Hope',
#  'Shard of Knowledge',
#  'Shard of Life',
#  'Shard of Pain',
#  'Shard of Strength',
#  'Shatter Storm',
#  'Shield of Justice',
#  'Shooler',
#  'Shoulder Armor',
#  'Sigil of Brotherhood',
#  'Signal Fire',
#  'Silent Dagger',
#  'Silver Key Imp',
#  'Silvertooth',
#  'Sir Marrows',
#  'Skeleton Key',
#  'Skippy Timehog',
#  'Skullion',
#  'Skybooster Squadron',
#  'Sloppy Labwork',
#  'Smaaash',
#  'Smiling Ruth',
#  'Smite',
#  'Smith',
#  'Sneklifter',
#  'Sniffer',
#  'Snudge',
#  'Snufflegator',
#  'Soft Landing',
#  'Soldiers to Flowers',
#  'Song of Spring',
#  'Soul Snatcher',
#  'Soulkeeper',
#  'Sound the Horns',
#  'Spangler Box',
#  'Special Delivery',
#  'Spectral Tunneler',
#  'Speed Sigil',
#  'Spyyyder',
#  'Squawker',
#  'Stampede',
#  'Standardized Testing',
#  'Staunch Knight',
#  'Stealer of Souls',
#  'Storm Crawler',
#  'Strange Gizmo',
#  'Streke',
#  'Subtle Maul',
#  'Succubus',
#  'Sucker Punch',
#  'Swap Widget',
#  'Swindle',
#  'Take Hostages',
#  'Take that, Smartypants',
#  'Tantadlin',
#  'Teliga',
#  'Tendrils of Pain',
#  'Tentacus',
#  'Terms of Redress',
#  'Tezmal',
#  'The Common Cold',
#  'The Curator',
#  'The Flex',
#  'The Grey Rider',
#  'The Harder They Come',
#  'The Howling Pit',
#  'The Spirit’s Way',
#  'The Sting',
#  'The Terror',
#  'The Vaultkeeper',
#  'The Warchest',
#  'They’re Everywhere!',
#  'Three Fates',
#  'Throwing Stars',
#  'Timetraveller',
#  'Tireless Crocag',
#  'Titan Librarian',
#  'Titan Mechanic',
#  'Tocsin',
#  'Tolas',
#  'Too Much to Protect',
#  'Total Recall',
#  'Transposition Sandals',
#  'Treasure Map',
#  'Tremor',
#  'Troll',
#  'Troop Call',
#  'Truebaru',
#  'Tunk',
#  'Twin Bolt Emission',
#  'Tyxl Beambuckler',
#  'Ulyq Megamouth',
#  'Umbra',
#  'Unguarded Camp',
#  'Unlocked Gateway',
#  'Untamed Ambassador',
#  'Urchin',
#  'Uxlyx the Zookeeper',
#  'Valdr',
#  'Veemos Lightbringer',
#  'Vespilon Theorist',
#  'Veylan Analyst',
#  'Vezyma Thinkdrone',
#  'Vigor',
#  'Virtuous Works',
#  'War Grumpus',
#  'Wardrummer',
#  'Warsong',
#  'Way of the Bear',
#  'Way of the Porcupine',
#  'Way of the Wolf',
#  'Whispering Reliquary',
#  'Whistling Darts',
#  'Wild Wormhole',
#  'Witch of the Eye',
#  'Witch of the Wilds',
#  'Word of Returning',
#  'World Tree',
#  'Wretched Doll',
#  'Xanthyx Harvester',
#  'Yantzee Gang',
#  'Yo Mama Mastery',
#  'Yurk',
#  'Yxili Marauder',
#  'Yxilo Bolter',
#  'Yxilx Dominator',
#  'Yxlyx Stimrager',
#  'Yzphyz Knowdrone',
#  'Z.Y.X. Researcher',
#  'Zorg',
#  'Zysysyx Shockworm',
#  'Zyzzix the Many',
#  '[REDACTED]',
#  'Æmber Conduction Unit',
#  'Æmber Imp',
#  'Æmberspine Mongrel',
#  '“John Smyth”',
#  '“Lion” Bautrem']

# %% [markdown]
# We would like to have a True False check to see if the card is in the deck. This is problematic as there are multiple card_ids for each card name. That would be tricky to match. Instead what we'll try do, is add a new column which has the card names instead of the card ids.

# %%
def change_card_ids_to_names(card_list):
    new_card_list = []
    start=2
    end=38
    for i in range(36):
        card = card_df.loc[(card_df['card_id'] == \
                           card_list[start:end])]['card_title'].item()
        new_card_list.append(card)
        start = start + 40
        end = end + 40
    return(new_card_list)

# %%
deck_df.iloc[0]['deck_list']
# Out:
# "['417b7845-2c67-4bcf-b411-20f2a7d86955', '920f3001-2f7a-4c21-b5b6-5d95fc5c0fef', '0ec85771-8143-4d64-8c3a-ce48bce4e81c', '4e6ddfb1-80bb-408c-9470-9a17120b96dc', 'eb3bd495-1d1a-45f6-941e-a0cf159431d1', 'bf88c08c-9cb3-4541-8330-5f209104c7d5', '3293f116-662c-4484-8951-accb4f25dd00', '69252efa-9686-4868-aca9-b8bc5af7cb8a', 'ef95c09f-7134-470c-8ddf-7ae1c84bbcb0', '52e8b81a-a716-4147-afcf-560bec2a3523', '16cdef01-a9d6-44d9-b0e0-247544e1db7f', 'b822fd9d-8209-49dd-b1b1-541f54641bf1', '0c75c0ba-d9ac-48f0-a1a2-72ae29000ea2', '17387482-a223-488a-a8ba-6911d691c281', '17387482-a223-488a-a8ba-6911d691c281', '9b5ad855-50f3-43e6-ad85-af95da564469', '29ddc45f-882b-4cb2-bb9b-efb91bd09e82', '7dcc8edb-ee57-4152-9b5d-cc012fa9973b', '7dcc8edb-ee57-4152-9b5d-cc012fa9973b', '7dcc8edb-ee57-4152-9b5d-cc012fa9973b', 'dc2f26d0-a6ab-4e15-b102-f23d6d26969b', '300dda74-ff5c-42e8-b17a-ff4eebc8109f', '77a3d587-3590-4fd3-80a1-1961f7c74ac7', 'dec37837-bdf2-4389-8204-92b75d32c9eb', 'eeac7978-6fa5-4c6a-a62e-144692ba93d6', '3ca70c14-4f07-46b4-b294-53b38b4bb987', '3ca70c14-4f07-46b4-b294-53b38b4bb987', '6ff72e74-35b9-4306-89e1-43101956ae3e', '74a2511a-7df8-4865-b125-cae3e4f0e41b', 'b81819bb-5687-452e-8582-182541142a23', '9ec01e67-b3f4-4ef7-8233-365f40da5fa8', '9b17219d-1ab4-41e6-95bf-00ba7a0dd938', '10f0c03b-1182-4ba1-9e85-2262643f81b3', '3b08ffe1-dc58-478c-94aa-4e7f40889552', '01d6a61c-7a02-4892-a6bc-b6d9f9da1266', 'd0e87df8-3bee-49bf-8c74-3456f05375a9']"

# %%
change_card_ids_to_names(deck_df.iloc[0]['deck_list'])
# Out:
# ['Bingle Bangbang',
#  'Cowfyne',
#  'First Blood',
#  'Foozle',
#  'Ganger Chieftain',
#  'Gauntlet of Command',
#  'Pound',
#  'Blood Money',
#  'Blood of Titans',
#  'Sound the Horns',
#  'The Flex',
#  'Tireless Crocag',
#  'Lash of Broken Dreams',
#  'Not Finished with You',
#  'Not Finished with You',
#  'Shooler',
#  'Streke',
#  'Yurk',
#  'Yurk',
#  'Yurk',
#  'Gongoozle',
#  'Pain Reaction',
#  'Pandemonium',
#  'Tentacus',
#  'Bordan the Redeemed',
#  'Challe the Safeguard',
#  'Challe the Safeguard',
#  'Golden Aura',
#  'Hallowed Shield',
#  'Maruck the Marked',
#  'Protect the Weak',
#  'Smite',
#  'The Grey Rider',
#  'Potion of Invulnerability',
#  'Duma the Martyr',
#  'Eye of Judgment']

# %% [markdown]
# This next bit takes some time.

# %%
deck_df['card_name_list'] = deck_df['deck_list'].apply(change_card_ids_to_names)

# %%
deck_df.iloc[0]
# Out:
# deck_id                        6216e565-a790-4e5b-b89a-4a814917b94e
# deck_name                    Leif “As”, Granjera de la Alcantarilla
# deck_wins                                                         2
# deck_losses                                                       1
# deck_expansion                                                  435
# deck_list         ['417b7845-2c67-4bcf-b411-20f2a7d86955', '920f...
# house_brobnar                                                  True
# house_dis                                                      True
# house_sanctum                                                  True
# house_mars                                                    False
# house_untamed                                                 False
# house_shadows                                                 False
# house_logos                                                   False
# card_name_list    [Bingle Bangbang, Cowfyne, First Blood, Foozle...
# Name: 0, dtype: object

# %% [markdown]
# The card name [REDACTED] causes problems later, so we rename to avoid this.

# %%
list_of_cards[568] = "REDACTED"

# %% [markdown]
# Now we can use a similar method as we did with the houses using a check to see if the name is included in the field. This cycles through the list of 574 card columns and counts the number of times the card name appears in the total card list string.

# %%
for n in list_of_cards:
    deck_df[n] = deck_df['card_name_list'].astype(str).str.count(n)

# %%
deck_df.iloc[0]
# Out:
# deck_id                               6216e565-a790-4e5b-b89a-4a814917b94e
# deck_name                           Leif “As”, Granjera de la Alcantarilla
# deck_wins                                                                2
# deck_losses                                                              1
# deck_expansion                                                         435
# deck_list                ['417b7845-2c67-4bcf-b411-20f2a7d86955', '920f...
# house_brobnar                                                         True
# house_dis                                                             True
# house_sanctum                                                         True
# house_mars                                                           False
# house_untamed                                                        False
# house_shadows                                                        False
# house_logos                                                          False
# card_name_list           [Bingle Bangbang, Cowfyne, First Blood, Foozle...
# 1-2 Punch                                                                0
# A Fair Game                                                              0
# Abond the Armorsmith                                                     0
# Agent Hoo-man                                                            0
# Ammonia Clouds                                                           0
# Anahita the Trader                                                       0
# Ancient Bear                                                             0
# Ancient Yurk                                                             0
# Anger                                                                    0
# Angwish                                                                  0
# Annihilation Ritual                                                      0
# Anomaly Exploiter                                                        0
# Archimedes                                                               0
# Arise!                                                                   0
# Armageddon Cloak                                                         0
# Aubade the Grim                                                          0
#                                                ...
# Way of the Bear                                                          0
# Way of the Porcupine                                                     0
# Way of the Wolf                                                          0
# Whispering Reliquary                                                     0
# Whistling Darts                                                          0
# Wild Wormhole                                                            0
# Witch of the Eye                                                         0
# Witch of the Wilds                                                       0
# Word of Returning                                                        0
# World Tree                                                               0
# Wretched Doll                                                            0
# Xanthyx Harvester                                                        0
# Yantzee Gang                                                             0
# Yo Mama Mastery                                                          0
# Yurk                                                                     3
# Yxili Marauder                                                           0
# Yxilo Bolter                                                             0
# Yxilx Dominator                                                          0
# Yxlyx Stimrager                                                          0
# Yzphyz Knowdrone                                                         0
# Z.Y.X. Researcher                                                        0
# Zorg                                                                     0
# Zysysyx Shockworm                                                        0
# Zyzzix the Many                                                          0
# REDACTED                                                                 0
# Æmber Conduction Unit                                                    0
# Æmber Imp                                                                0
# Æmberspine Mongrel                                                       0
# “John Smyth”                                                             0
# “Lion” Bautrem                                                           0
# Name: 0, Length: 588, dtype: object

# %% [markdown]
# Next we want to assign a 'score' to each deck, this will be our target variable. In this case we are going to take the number of wins and subtract the number of losses.

# %%
deck_df.describe()
# Out:
#           deck_wins   deck_losses  deck_expansion     1-2 Punch   A Fair Game  \
# count  67321.000000  67321.000000    67321.000000  67321.000000  67321.000000
# mean       2.520833      2.340949      373.913474      0.066294      0.025638
# std        2.452996      1.786724       44.839711      0.298569      0.160109
# min        0.000000      0.000000      341.000000      0.000000      0.000000
# 25%        1.000000      1.000000      341.000000      0.000000      0.000000
# 50%        2.000000      2.000000      341.000000      0.000000      0.000000
# 75%        3.000000      3.000000      435.000000      0.000000      0.000000
# max       40.000000     39.000000      435.000000      4.000000      2.000000
#
#        Abond the Armorsmith  Agent Hoo-man  Ammonia Clouds  \
# count          67321.000000   67321.000000    67321.000000
# mean               0.070513       0.066606        0.103593
# std                0.309012       0.300557        0.368056
# min                0.000000       0.000000        0.000000
# 25%                0.000000       0.000000        0.000000
# 50%                0.000000       0.000000        0.000000
# 75%                0.000000       0.000000        0.000000
# max                4.000000       4.000000        4.000000
#
#        Anahita the Trader  Ancient Bear  ...  Z.Y.X. Researcher          Zorg  \
# count        67321.000000  67321.000000  ...       67321.000000  67321.000000
# mean             0.007977      0.139615  ...           0.084758      0.064660
# std              0.089952      0.434456  ...           0.341704      0.266174
# min              0.000000      0.000000  ...           0.000000      0.000000
# 25%              0.000000      0.000000  ...           0.000000      0.000000
# 50%              0.000000      0.000000  ...           0.000000      0.000000
# 75%              0.000000      0.000000  ...           0.000000      0.000000
# max              2.000000      4.000000  ...           4.000000      3.000000
#
#        Zysysyx Shockworm  Zyzzix the Many      REDACTED  \
# count       67321.000000     67321.000000  67321.000000
# mean            0.068909         0.115061      0.010101
# std             0.305654         0.393665      0.103355
# min             0.000000         0.000000      0.000000
# 25%             0.000000         0.000000      0.000000
# 50%             0.000000         0.000000      0.000000
# 75%             0.000000         0.000000      0.000000
# max             4.000000         4.000000      2.000000
#
#        Æmber Conduction Unit     Æmber Imp  Æmberspine Mongrel  “John Smyth”  \
# count           67321.000000  67321.000000        67321.000000  67321.000000
# mean                0.023633      0.073424            0.028253      0.123127
# std                 0.164938      0.311640            0.179880      0.411228
# min                 0.000000      0.000000            0.000000      0.000000
# 25%                 0.000000      0.000000            0.000000      0.000000
# 50%                 0.000000      0.000000            0.000000      0.000000
# 75%                 0.000000      0.000000            0.000000      0.000000
# max                 3.000000      4.000000            3.000000      5.000000
#
#        “Lion” Bautrem
# count    67321.000000
# mean         0.075638
# std          0.321604
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          4.000000
#
# [8 rows x 577 columns]

# %%
deck_df['score'] = deck_df['deck_wins'] - deck_df['deck_losses']

# %%
deck_df.iloc[0]['score']
# Out:
# 1

# %% [markdown]
# Almost there. Now we're going to tidy up a little. We remove the columns we no longer need and we're adjusting the name on the expansion which currently is a numeric.

# %%
deck_df.loc[deck_df.deck_expansion == 435, 'expansion'] = True #'Call of the Archons'
deck_df.loc[deck_df.deck_expansion == 341, 'expansion'] = False #'Age of Ascension'

# %%
deck_df = deck_df.drop("deck_expansion", axis=1)
deck_df = deck_df.drop("deck_list", axis=1)
deck_df = deck_df.drop("card_name_list", axis=1)

# %%
deck_df.loc[0]
# Out:
# deck_id                    6216e565-a790-4e5b-b89a-4a814917b94e
# deck_name                Leif “As”, Granjera de la Alcantarilla
# deck_wins                                                     2
# deck_losses                                                   1
# house_brobnar                                              True
# house_dis                                                  True
# house_sanctum                                              True
# house_mars                                                False
# house_untamed                                             False
# house_shadows                                             False
# house_logos                                               False
# 1-2 Punch                                                     0
# A Fair Game                                                   0
# Abond the Armorsmith                                          0
# Agent Hoo-man                                                 0
# Ammonia Clouds                                                0
# Anahita the Trader                                            0
# Ancient Bear                                                  0
# Ancient Yurk                                                  0
# Anger                                                         0
# Angwish                                                       0
# Annihilation Ritual                                           0
# Anomaly Exploiter                                             0
# Archimedes                                                    0
# Arise!                                                        0
# Armageddon Cloak                                              0
# Aubade the Grim                                               0
# Autocannon                                                    0
# Backup Copy                                                   0
# Bad Penny                                                     0
#                                           ...
# Way of the Wolf                                               0
# Whispering Reliquary                                          0
# Whistling Darts                                               0
# Wild Wormhole                                                 0
# Witch of the Eye                                              0
# Witch of the Wilds                                            0
# Word of Returning                                             0
# World Tree                                                    0
# Wretched Doll                                                 0
# Xanthyx Harvester                                             0
# Yantzee Gang                                                  0
# Yo Mama Mastery                                               0
# Yurk                                                          3
# Yxili Marauder                                                0
# Yxilo Bolter                                                  0
# Yxilx Dominator                                               0
# Yxlyx Stimrager                                               0
# Yzphyz Knowdrone                                              0
# Z.Y.X. Researcher                                             0
# Zorg                                                          0
# Zysysyx Shockworm                                             0
# Zyzzix the Many                                               0
# REDACTED                                                      0
# Æmber Conduction Unit                                         0
# Æmber Imp                                                     0
# Æmberspine Mongrel                                            0
# “John Smyth”                                                  0
# “Lion” Bautrem                                                0
# score                                                         1
# expansion                                                  True
# Name: 0, Length: 587, dtype: object

# %%
deck_df.to_csv("data/data_decks_cleaned.csv", header=True, index=False)

# %% [markdown]
# Data prep ends here
#
# ------------------------------------------------------
