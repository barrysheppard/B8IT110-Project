# %% [markdown]
# # Project

# %% [markdown]
# The aim of this Capstone project is to consolidate the knowledge, skills and competences acquired by learners during this programme. In this project students will select, specify, design, justify and implement a data analytics investigation that makes use of large data sets. The project will necessarily require data ingestion, wrangling, computation and analyses, and the production and presentation of a project and report. Students are guided by faculty in the selection of a data set, scope of investigation, initial exploratory data analysis, and formulation of hypotheses.

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import ast

# %%
new_deck_df = pd.read_csv("Winning_Decks.csv")

# %%
card_df = pd.read_csv("Cards.csv")

# %%
print(new_deck_df.iloc[0]['houses'])
# Out:
# ['Brobnar', 'Dis', 'Sanctum']

# %%
print(new_deck_df.iloc[0]['deck_list'])
# Out:
# ['417b7845-2c67-4bcf-b411-20f2a7d86955'
#  '920f3001-2f7a-4c21-b5b6-5d95fc5c0fef'
#  '0ec85771-8143-4d64-8c3a-ce48bce4e81c'
#  '4e6ddfb1-80bb-408c-9470-9a17120b96dc'
#  'eb3bd495-1d1a-45f6-941e-a0cf159431d1'
#  'bf88c08c-9cb3-4541-8330-5f209104c7d5'
#  '3293f116-662c-4484-8951-accb4f25dd00'
#  '69252efa-9686-4868-aca9-b8bc5af7cb8a'
#  'ef95c09f-7134-470c-8ddf-7ae1c84bbcb0'
#  '52e8b81a-a716-4147-afcf-560bec2a3523'
#  '16cdef01-a9d6-44d9-b0e0-247544e1db7f'
#  'b822fd9d-8209-49dd-b1b1-541f54641bf1'
#  '0c75c0ba-d9ac-48f0-a1a2-72ae29000ea2'
#  '17387482-a223-488a-a8ba-6911d691c281'
#  '17387482-a223-488a-a8ba-6911d691c281'
#  '9b5ad855-50f3-43e6-ad85-af95da564469'
#  '29ddc45f-882b-4cb2-bb9b-efb91bd09e82'
#  '7dcc8edb-ee57-4152-9b5d-cc012fa9973b'
#  '7dcc8edb-ee57-4152-9b5d-cc012fa9973b'
#  '7dcc8edb-ee57-4152-9b5d-cc012fa9973b'
#  'dc2f26d0-a6ab-4e15-b102-f23d6d26969b'
#  '300dda74-ff5c-42e8-b17a-ff4eebc8109f'
#  '77a3d587-3590-4fd3-80a1-1961f7c74ac7'
#  'dec37837-bdf2-4389-8204-92b75d32c9eb'
#  'eeac7978-6fa5-4c6a-a62e-144692ba93d6'
#  '3ca70c14-4f07-46b4-b294-53b38b4bb987'
#  '3ca70c14-4f07-46b4-b294-53b38b4bb987'
#  '6ff72e74-35b9-4306-89e1-43101956ae3e'
#  '74a2511a-7df8-4865-b125-cae3e4f0e41b'
#  'b81819bb-5687-452e-8582-182541142a23'
#  '9ec01e67-b3f4-4ef7-8233-365f40da5fa8'
#  '9b17219d-1ab4-41e6-95bf-00ba7a0dd938'
#  '10f0c03b-1182-4ba1-9e85-2262643f81b3'
#  '3b08ffe1-dc58-478c-94aa-4e7f40889552'
#  '01d6a61c-7a02-4892-a6bc-b6d9f9da1266'
#  'd0e87df8-3bee-49bf-8c74-3456f05375a9']

# %%
print(new_deck_df.loc[0]['deck_list'][2:38])
# Out:
# 417b7845-2c67-4bcf-b411-20f2a7d86955

# %%
print(card_df.loc[(card_df['card_id'] == new_deck_df.loc[0]['deck_list'][2:38])]['card_title'].item())
# Out:
# Bingle Bangbang

# %%
print(new_deck_df.loc[0]['deck_list'][42:78])
# Out:
# 920f3001-2f7a-4c21-b5b6-5d95fc5c0fef

# %%
print(card_df.loc[(card_df['card_id'] == new_deck_df.loc[0]['deck_list'][42:78])]['card_title'].item())
# Out:
# Cowfyne

# %%
start=2
end=38
print(new_deck_df.loc[0]['deck_list'][start:end])
# Out:
# 417b7845-2c67-4bcf-b411-20f2a7d86955

# %%
start=2
end=38
for i in range(36):
    print(new_deck_df.loc[0]['deck_list'][start:end])
    start = start + 40
    end = end + 40
# Out:
# 417b7845-2c67-4bcf-b411-20f2a7d86955
# 920f3001-2f7a-4c21-b5b6-5d95fc5c0fef
# 0ec85771-8143-4d64-8c3a-ce48bce4e81c
# 4e6ddfb1-80bb-408c-9470-9a17120b96dc
# eb3bd495-1d1a-45f6-941e-a0cf159431d1
# bf88c08c-9cb3-4541-8330-5f209104c7d5
# 3293f116-662c-4484-8951-accb4f25dd00
# 69252efa-9686-4868-aca9-b8bc5af7cb8a
# ef95c09f-7134-470c-8ddf-7ae1c84bbcb0
# 52e8b81a-a716-4147-afcf-560bec2a3523
# 16cdef01-a9d6-44d9-b0e0-247544e1db7f
# b822fd9d-8209-49dd-b1b1-541f54641bf1
# 0c75c0ba-d9ac-48f0-a1a2-72ae29000ea2
# 17387482-a223-488a-a8ba-6911d691c281
# 17387482-a223-488a-a8ba-6911d691c281
# 9b5ad855-50f3-43e6-ad85-af95da564469
# 29ddc45f-882b-4cb2-bb9b-efb91bd09e82
# 7dcc8edb-ee57-4152-9b5d-cc012fa9973b
# 7dcc8edb-ee57-4152-9b5d-cc012fa9973b
# 7dcc8edb-ee57-4152-9b5d-cc012fa9973b
# dc2f26d0-a6ab-4e15-b102-f23d6d26969b
# 300dda74-ff5c-42e8-b17a-ff4eebc8109f
# 77a3d587-3590-4fd3-80a1-1961f7c74ac7
# dec37837-bdf2-4389-8204-92b75d32c9eb
# eeac7978-6fa5-4c6a-a62e-144692ba93d6
# 3ca70c14-4f07-46b4-b294-53b38b4bb987
# 3ca70c14-4f07-46b4-b294-53b38b4bb987
# 6ff72e74-35b9-4306-89e1-43101956ae3e
# 74a2511a-7df8-4865-b125-cae3e4f0e41b
# b81819bb-5687-452e-8582-182541142a23
# 9ec01e67-b3f4-4ef7-8233-365f40da5fa8
# 9b17219d-1ab4-41e6-95bf-00ba7a0dd938
# 10f0c03b-1182-4ba1-9e85-2262643f81b3
# 3b08ffe1-dc58-478c-94aa-4e7f40889552
# 01d6a61c-7a02-4892-a6bc-b6d9f9da1266
# d0e87df8-3bee-49bf-8c74-3456f05375a9

# %%
start=2
end=38
for i in range(36):
    print(card_df.loc[(card_df['card_id'] == \
                       new_deck_df.loc[1]['deck_list'][start:end])]['card_title'].item())
    start = start + 40
    end = end + 40
# Out:
# Drummernaut
# Drummernaut
# First Blood
# Ganger Chieftain
# Ganger Chieftain
# Groggins
# Groke
# Groke
# Into the Fray
# Lollop the Titanic
# Tremor
# Barehanded
# Abond the Armorsmith
# Blinding Light
# Bordan the Redeemed
# Challe the Safeguard
# Sir Marrows
# Smite
# Take Hostages
# The Grey Rider
# The Grey Rider
# Haedroth’s Wall
# Prince Derric, Unifier
# The Vaultkeeper
# Duskwitch
# Grovekeeper
# Key Charge
# Regrowth
# Rustgnawer
# Tantadlin
# They’re Everywhere!
# Grasping Vines
# Grasping Vines
# Panpaca, Anga
# Panpaca, Anga
# Quicksand

# %%
house_length = len(new_deck_df.loc[2]['houses'])
houses = new_deck_df.loc[2]['houses'][2:house_length-2].split("', '")
print(houses[0])
print(houses[1])
print(houses[2])
# Out:
# Brobnar
# Mars
# Sanctum

# %%
new_card_list = []
start=2
end=38
for i in range(36):
    card = card_df.loc[(card_df['card_id'] == \
                       new_deck_df.loc[1]['deck_list'][start:end])]['card_title'].item()
    new_card_list.append(card)
    start = start + 40
    end = end + 40
print(new_card_list)
# Out:
# ['Drummernaut', 'Drummernaut', 'First Blood', 'Ganger Chieftain', 'Ganger Chieftain', 'Groggins', 'Groke', 'Groke', 'Into the Fray', 'Lollop the Titanic', 'Tremor', 'Barehanded', 'Abond the Armorsmith', 'Blinding Light', 'Bordan the Redeemed', 'Challe the Safeguard', 'Sir Marrows', 'Smite', 'Take Hostages', 'The Grey Rider', 'The Grey Rider', 'Haedroth’s Wall', 'Prince Derric, Unifier', 'The Vaultkeeper', 'Duskwitch', 'Grovekeeper', 'Key Charge', 'Regrowth', 'Rustgnawer', 'Tantadlin', 'They’re Everywhere!', 'Grasping Vines', 'Grasping Vines', 'Panpaca, Anga', 'Panpaca, Anga', 'Quicksand']

# %%
house_length = len(new_deck_df.loc[2]['houses'])
houses = new_deck_df.loc[2]['houses'][2:house_length-2].split("', '")
print(houses)
# Out:
# ['Brobnar', 'Mars', 'Sanctum']

# %% [markdown]
# The next thing we want to be able to do is change the data so it has a single row for each card. In this case we want the current details we have for each deck repeated.

# %%
print(new_deck_df.iloc[1])
# Out:
# Unnamed: 0                                                       25
# Unnamed: 0.1                                                      0
# deck_id                        50e28cdd-6e6b-4584-a8d1-1f22c081e906
# deck_name                           “Ivan” Valencia, Ship Chieftain
# deck_wins                                                         1
# deck_losses                                                       3
# deck_expansion                                                  435
# deck_list         ['2ee769bb-b785-48ea-a5fa-a19a2af32bbc'\n '2ee...
# houses                            ['Brobnar', 'Sanctum', 'Untamed']
# Name: 1, dtype: object

# %%
print(new_deck_df.iloc[1]['deck_id'], new_deck_df.iloc[1]['deck_name'], new_deck_df.iloc[1]['deck_wins'], new_deck_df.iloc[1]['deck_losses'], new_deck_df.iloc[1]['deck_expansion'], new_deck_df.iloc[1]['deck_expansion'])
# Out:
# 50e28cdd-6e6b-4584-a8d1-1f22c081e906 “Ivan” Valencia, Ship Chieftain 1 3 435 435

# %%
deck_list = [card_df.iloc[1]['card_id'],card_df.iloc[1]['card_title'],'']

# %% [markdown]
# Lets see if we can plot anything

# %%
# %matplotlib inline

# %%
new_deck_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                               deck_id  \
# 0           3             3  6216e565-a790-4e5b-b89a-4a814917b94e
# 1          25             0  50e28cdd-6e6b-4584-a8d1-1f22c081e906
# 2          28             3  3969e139-05d7-4a8a-ba60-0bb660cd057b
# 3          31             6  5668bdc3-dea4-4226-92ba-91b003a5460e
# 4          44            19  749780f6-7acb-402a-9fd6-f6fbbcf888e1
#
#                                   deck_name  deck_wins  deck_losses  \
# 0    Leif “As”, Granjera de la Alcantarilla          2            1
# 1           “Ivan” Valencia, Ship Chieftain          1            3
# 2                  Nasir, Canal Survivalist          2            1
# 3           Destrolack, Observatory Recluse          4            4
# 4  Tiberius, Navigatore della Guglia Aperta          8            4
#
#    deck_expansion                                          deck_list  \
# 0             435  ['417b7845-2c67-4bcf-b411-20f2a7d86955'\n '920...
# 1             435  ['2ee769bb-b785-48ea-a5fa-a19a2af32bbc'\n '2ee...
# 2             435  ['a3234c40-8226-439d-bb8f-207ea26c9560'\n '920...
# 3             435  ['7bf05cd5-7c03-4e06-9ace-bb730ff6100e'\n '7bf...
# 4             341  ['753bfb51-4ba7-4c0a-b141-a5b6388498c0'\n 'aee...
#
#                               houses
# 0      ['Brobnar', 'Dis', 'Sanctum']
# 1  ['Brobnar', 'Sanctum', 'Untamed']
# 2     ['Brobnar', 'Mars', 'Sanctum']
# 3    ['Logos', 'Sanctum', 'Untamed']
# 4     ['Mars', 'Shadows', 'Untamed']

# %%
new_deck_df.describe()
# Out:
#          Unnamed: 0  Unnamed: 0.1     deck_wins   deck_losses  deck_expansion
# count  59840.000000  59840.000000  59840.000000  59840.000000    59840.000000
# mean   22222.906618     12.055180      2.789004      2.274499      372.833389
# std    13979.948589      7.211019      2.444614      1.837420       44.486031
# min        0.000000      0.000000      1.000000      0.000000      341.000000
# 25%    10237.000000      6.000000      1.000000      1.000000      341.000000
# 50%    21047.500000     12.000000      2.000000      2.000000      341.000000
# 75%    33161.500000     18.000000      3.000000      3.000000      435.000000
# max    56093.000000     24.000000     40.000000     39.000000      435.000000

# %%
decks = new_deck_df[['deck_wins','deck_losses','deck_expansion']]
decks.head()
# Out:
#    deck_wins  deck_losses  deck_expansion
# 0          2            1             435
# 1          1            3             435
# 2          2            1             435
# 3          4            4             435
# 4          8            4             341

# %%
deck_exp = decks.groupby('deck_expansion')
deck_exp.size()
# Out:
# deck_expansion
# 341    39575
# 435    20265
# dtype: int64

# %%
deck_exp_totals = deck_exp.sum()
deck_exp_totals.head()
# Out:
#                 deck_wins  deck_losses
# deck_expansion
# 341                117962        93776
# 435                 48932        42330

# %%
my_plot = deck_exp_totals.plot(kind='bar')

# %%
house_length = len(new_deck_df.loc[2]['houses'])
houses = new_deck_df.loc[2]['houses'][2:house_length-2].split("', '")
print(houses[0])
print(houses[1])
print(houses[2])
# Out:
# Brobnar
# Mars
# Sanctum

# %% [markdown]
# We want to create a new data frame from the original deck dataframe but replacing each deck row with 3 rows one for each house.

# %%
new_deck_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                               deck_id  \
# 0           3             3  6216e565-a790-4e5b-b89a-4a814917b94e
# 1          25             0  50e28cdd-6e6b-4584-a8d1-1f22c081e906
# 2          28             3  3969e139-05d7-4a8a-ba60-0bb660cd057b
# 3          31             6  5668bdc3-dea4-4226-92ba-91b003a5460e
# 4          44            19  749780f6-7acb-402a-9fd6-f6fbbcf888e1
#
#                                   deck_name  deck_wins  deck_losses  \
# 0    Leif “As”, Granjera de la Alcantarilla          2            1
# 1           “Ivan” Valencia, Ship Chieftain          1            3
# 2                  Nasir, Canal Survivalist          2            1
# 3           Destrolack, Observatory Recluse          4            4
# 4  Tiberius, Navigatore della Guglia Aperta          8            4
#
#    deck_expansion                                          deck_list  \
# 0             435  ['417b7845-2c67-4bcf-b411-20f2a7d86955'\n '920...
# 1             435  ['2ee769bb-b785-48ea-a5fa-a19a2af32bbc'\n '2ee...
# 2             435  ['a3234c40-8226-439d-bb8f-207ea26c9560'\n '920...
# 3             435  ['7bf05cd5-7c03-4e06-9ace-bb730ff6100e'\n '7bf...
# 4             341  ['753bfb51-4ba7-4c0a-b141-a5b6388498c0'\n 'aee...
#
#                               houses
# 0      ['Brobnar', 'Dis', 'Sanctum']
# 1  ['Brobnar', 'Sanctum', 'Untamed']
# 2     ['Brobnar', 'Mars', 'Sanctum']
# 3    ['Logos', 'Sanctum', 'Untamed']
# 4     ['Mars', 'Shadows', 'Untamed']

# %%
house_deck_df = pd.DataFrame(columns=['deck_id', 'deck_name', 'deck_wins', 'deck_losses', 'deck_expansion', 'deck_house'])
house_deck_df
# Out:
# Empty DataFrame
# Columns: [deck_id, deck_name, deck_wins, deck_losses, deck_expansion, deck_house]
# Index: []

# %%
columns = ['deck_id', 'deck_name', 'deck_wins', 'deck_losses', 'deck_expansion', 'deck_house']

# %%
print(len(new_deck_df))
# Out:
# 59840

# %%
result_df = pd.DataFrame([], columns = columns)

# %%
for n in range(0, len(new_deck_df)-1):
    house_length = len(new_deck_df.loc[n]['houses'])
    houses = new_deck_df.loc[n]['houses'][2:house_length-2].split("', '")
    house_list = []
    for i in houses:
        new_row = [new_deck_df.iloc[n]["deck_id"], new_deck_df.iloc[n]["deck_name"], new_deck_df.iloc[n]["deck_wins"], new_deck_df.iloc[n]["deck_losses"], new_deck_df.iloc[n]["deck_expansion"], i]
        house_list.append(new_row)
    df = pd.DataFrame(house_list, columns = columns)
    result_df = result_df.append(df)
result_df
# Out:
#                                  deck_id  \
# 0   6216e565-a790-4e5b-b89a-4a814917b94e
# 1   6216e565-a790-4e5b-b89a-4a814917b94e
# 2   6216e565-a790-4e5b-b89a-4a814917b94e
# 0   6216e565-a790-4e5b-b89a-4a814917b94e
# 1   6216e565-a790-4e5b-b89a-4a814917b94e
# 2   6216e565-a790-4e5b-b89a-4a814917b94e
# 0   50e28cdd-6e6b-4584-a8d1-1f22c081e906
# 1   50e28cdd-6e6b-4584-a8d1-1f22c081e906
# 2   50e28cdd-6e6b-4584-a8d1-1f22c081e906
# 0   3969e139-05d7-4a8a-ba60-0bb660cd057b
# 1   3969e139-05d7-4a8a-ba60-0bb660cd057b
# 2   3969e139-05d7-4a8a-ba60-0bb660cd057b
# 0   5668bdc3-dea4-4226-92ba-91b003a5460e
# 1   5668bdc3-dea4-4226-92ba-91b003a5460e
# 2   5668bdc3-dea4-4226-92ba-91b003a5460e
# 0   749780f6-7acb-402a-9fd6-f6fbbcf888e1
# 1   749780f6-7acb-402a-9fd6-f6fbbcf888e1
# 2   749780f6-7acb-402a-9fd6-f6fbbcf888e1
# 0   bb3a84fe-adc2-4d9b-b451-57f1581101ff
# 1   bb3a84fe-adc2-4d9b-b451-57f1581101ff
# 2   bb3a84fe-adc2-4d9b-b451-57f1581101ff
# 0   584ba39e-4e7c-4c80-ba04-036de05301ff
# 1   584ba39e-4e7c-4c80-ba04-036de05301ff
# 2   584ba39e-4e7c-4c80-ba04-036de05301ff
# 0   f363f66c-a5ef-436b-8cdd-e31e4de96095
# 1   f363f66c-a5ef-436b-8cdd-e31e4de96095
# 2   f363f66c-a5ef-436b-8cdd-e31e4de96095
# 0   e4ba17a0-41d5-4b2f-9370-0838bb4588af
# 1   e4ba17a0-41d5-4b2f-9370-0838bb4588af
# 2   e4ba17a0-41d5-4b2f-9370-0838bb4588af
# ..                                   ...
# 0   c548f0f9-5141-4bc4-83d4-b22d9342add1
# 1   c548f0f9-5141-4bc4-83d4-b22d9342add1
# 2   c548f0f9-5141-4bc4-83d4-b22d9342add1
# 0   1269c29e-a7a9-4a1b-8449-ec28f15942b5
# 1   1269c29e-a7a9-4a1b-8449-ec28f15942b5
# 2   1269c29e-a7a9-4a1b-8449-ec28f15942b5
# 0   444a9882-cf7e-4f4b-be4e-8510880e7d4e
# 1   444a9882-cf7e-4f4b-be4e-8510880e7d4e
# 2   444a9882-cf7e-4f4b-be4e-8510880e7d4e
# 0   1adaf669-a655-417e-b0b5-6c39783cfe5e
# 1   1adaf669-a655-417e-b0b5-6c39783cfe5e
# 2   1adaf669-a655-417e-b0b5-6c39783cfe5e
# 0   9528c6b4-ee5b-45e6-bf99-5e96b33eb9b5
# 1   9528c6b4-ee5b-45e6-bf99-5e96b33eb9b5
# 2   9528c6b4-ee5b-45e6-bf99-5e96b33eb9b5
# 0   952a0e18-f718-4b98-9b40-8200151abc79
# 1   952a0e18-f718-4b98-9b40-8200151abc79
# 2   952a0e18-f718-4b98-9b40-8200151abc79
# 0   37d3df77-3dbc-4665-959a-44460e044d4c
# 1   37d3df77-3dbc-4665-959a-44460e044d4c
# 2   37d3df77-3dbc-4665-959a-44460e044d4c
# 0   e849f1bc-ef87-40ea-a5d0-facdd902689a
# 1   e849f1bc-ef87-40ea-a5d0-facdd902689a
# 2   e849f1bc-ef87-40ea-a5d0-facdd902689a
# 0   7afa9552-6ba1-4966-ae2d-c64a128ede78
# 1   7afa9552-6ba1-4966-ae2d-c64a128ede78
# 2   7afa9552-6ba1-4966-ae2d-c64a128ede78
# 0   f886af3a-fef7-4e1f-bfb7-934578ff9e46
# 1   f886af3a-fef7-4e1f-bfb7-934578ff9e46
# 2   f886af3a-fef7-4e1f-bfb7-934578ff9e46
#
#                                      deck_name deck_wins deck_losses  \
# 0       Leif “As”, Granjera de la Alcantarilla         2           1
# 1       Leif “As”, Granjera de la Alcantarilla         2           1
# 2       Leif “As”, Granjera de la Alcantarilla         2           1
# 0       Leif “As”, Granjera de la Alcantarilla         2           1
# 1       Leif “As”, Granjera de la Alcantarilla         2           1
# 2       Leif “As”, Granjera de la Alcantarilla         2           1
# 0              “Ivan” Valencia, Ship Chieftain         1           3
# 1              “Ivan” Valencia, Ship Chieftain         1           3
# 2              “Ivan” Valencia, Ship Chieftain         1           3
# 0                     Nasir, Canal Survivalist         2           1
# 1                     Nasir, Canal Survivalist         2           1
# 2                     Nasir, Canal Survivalist         2           1
# 0              Destrolack, Observatory Recluse         4           4
# 1              Destrolack, Observatory Recluse         4           4
# 2              Destrolack, Observatory Recluse         4           4
# 0     Tiberius, Navigatore della Guglia Aperta         8           4
# 1     Tiberius, Navigatore della Guglia Aperta         8           4
# 2     Tiberius, Navigatore della Guglia Aperta         8           4
# 0         The Trivial Duke Rebel of Pinegrowth         2           2
# 1         The Trivial Duke Rebel of Pinegrowth         2           2
# 2         The Trivial Duke Rebel of Pinegrowth         2           2
# 0          Egle l’Apatica, Tenente del Veliero         2           2
# 1          Egle l’Apatica, Tenente del Veliero         2           2
# 2          Egle l’Apatica, Tenente del Veliero         2           2
# 0             Squareis, the “Whale” of Alchemy         2           2
# 1             Squareis, the “Whale” of Alchemy         2           2
# 2             Squareis, the “Whale” of Alchemy         2           2
# 0         Q. P. Exinome of the Endless Nursery         1           2
# 1         Q. P. Exinome of the Endless Nursery         1           2
# 2         Q. P. Exinome of the Endless Nursery         1           2
# ..                                         ...       ...         ...
# 0                Maeva “Lionne” la fastidieuse         1           2
# 1                Maeva “Lionne” la fastidieuse         1           2
# 2                Maeva “Lionne” la fastidieuse         1           2
# 0                                Sov G. Celard         2           2
# 1                                Sov G. Celard         2           2
# 2                                Sov G. Celard         2           2
# 0        Nysa, Podpalaczka z Błękitnej Karczmy         2           2
# 1        Nysa, Podpalaczka z Błękitnej Karczmy         2           2
# 2        Nysa, Podpalaczka z Błękitnej Karczmy         2           2
# 0   P. D. Che Divide la Saccenza dell’Archivio         1           3
# 1   P. D. Che Divide la Saccenza dell’Archivio         1           3
# 2   P. D. Che Divide la Saccenza dell’Archivio         1           3
# 0             Carbocloud, the Knight of Eagles         1           2
# 1             Carbocloud, the Knight of Eagles         1           2
# 2             Carbocloud, the Knight of Eagles         1           2
# 0                  Lachlan, Conservatory Magus         3           0
# 1                  Lachlan, Conservatory Magus         3           0
# 2                  Lachlan, Conservatory Magus         3           0
# 0                  “Dynamite” Styx, Crypt Pawn         3           0
# 1                  “Dynamite” Styx, Crypt Pawn         3           0
# 2                  “Dynamite” Styx, Crypt Pawn         3           0
# 0      Laila la Cíclope, Erudita de la Dársena         1           3
# 1      Laila la Cíclope, Erudita de la Dársena         1           3
# 2      Laila la Cíclope, Erudita de la Dársena         1           3
# 0       Jadon „Das Bärchen“, Wesir der Bastion         1           2
# 1       Jadon „Das Bärchen“, Wesir der Bastion         1           2
# 2       Jadon „Das Bärchen“, Wesir der Bastion         1           2
# 0                         Captain W. Titangard         1           3
# 1                         Captain W. Titangard         1           3
# 2                         Captain W. Titangard         1           3
#
#    deck_expansion deck_house
# 0             435    Brobnar
# 1             435        Dis
# 2             435    Sanctum
# 0             435    Brobnar
# 1             435        Dis
# 2             435    Sanctum
# 0             435    Brobnar
# 1             435    Sanctum
# 2             435    Untamed
# 0             435    Brobnar
# 1             435       Mars
# 2             435    Sanctum
# 0             435      Logos
# 1             435    Sanctum
# 2             435    Untamed
# 0             341       Mars
# 1             341    Shadows
# 2             341    Untamed
# 0             435    Brobnar
# 1             435       Mars
# 2             435    Sanctum
# 0             435        Dis
# 1             435    Sanctum
# 2             435    Shadows
# 0             435        Dis
# 1             435      Logos
# 2             435       Mars
# 0             435    Brobnar
# 1             435       Mars
# 2             435    Sanctum
# ..            ...        ...
# 0             435        Dis
# 1             435      Logos
# 2             435    Untamed
# 0             435    Sanctum
# 1             435    Shadows
# 2             435    Untamed
# 0             341      Logos
# 1             341       Mars
# 2             341    Shadows
# 0             435    Brobnar
# 1             435        Dis
# 2             435    Sanctum
# 0             435        Dis
# 1             435    Sanctum
# 2             435    Shadows
# 0             435        Dis
# 1             435      Logos
# 2             435    Sanctum
# 0             435        Dis
# 1             435       Mars
# 2             435    Shadows
# 0             435    Brobnar
# 1             435        Dis
# 2             435    Sanctum
# 0             341    Brobnar
# 1             341      Logos
# 2             341    Sanctum
# 0             435       Mars
# 1             435    Sanctum
# 2             435    Untamed
#
# [179520 rows x 6 columns]

# %%
decks = result_df[['deck_wins','deck_losses','deck_house']]
deck_exp = decks.groupby('deck_house')
deck_exp.size()
deck_exp_totals = deck_exp.sum()
deck_exp_totals.head()
my_plot = deck_exp_totals.plot(kind='bar')

# %% [markdown]
# Lets see if we can do similar with cards for decks

# %%
total = len(new_deck_df)-1
total = 1
column_names = ['deck_id', 'deck_name', 'deck_wins', 'deck_losses', 'deck_expansion', 'card_name']
result_df = pd.DataFrame(columns=columns)

# %%
for n in range(0, total):
    start=2
    end=38
    new_row_list = []
    for i in range(36):
        card_name = card_df.loc[(card_df['card_id'] == \
                                 new_deck_df.loc[1]['deck_list'][start:end])]['card_title'].item()
        new_row = [new_deck_df.iloc[n]["deck_id"],
                   new_deck_df.iloc[n]["deck_name"],
                   new_deck_df.iloc[n]["deck_wins"],
                   new_deck_df.iloc[n]["deck_losses"],
                   new_deck_df.iloc[n]["deck_expansion"],
                   card_name]
        start = start + 40
        end = end + 40
        new_row_list.append(new_row)
    new_row_df = pd.DataFrame(new_row_list, columns = column_names)
    result_df = result_df.append(new_row_df)
result_df
# Out:
#                                  deck_id  \
# 0   6216e565-a790-4e5b-b89a-4a814917b94e
# 1   6216e565-a790-4e5b-b89a-4a814917b94e
# 2   6216e565-a790-4e5b-b89a-4a814917b94e
# 3   6216e565-a790-4e5b-b89a-4a814917b94e
# 4   6216e565-a790-4e5b-b89a-4a814917b94e
# 5   6216e565-a790-4e5b-b89a-4a814917b94e
# 6   6216e565-a790-4e5b-b89a-4a814917b94e
# 7   6216e565-a790-4e5b-b89a-4a814917b94e
# 8   6216e565-a790-4e5b-b89a-4a814917b94e
# 9   6216e565-a790-4e5b-b89a-4a814917b94e
# 10  6216e565-a790-4e5b-b89a-4a814917b94e
# 11  6216e565-a790-4e5b-b89a-4a814917b94e
# 12  6216e565-a790-4e5b-b89a-4a814917b94e
# 13  6216e565-a790-4e5b-b89a-4a814917b94e
# 14  6216e565-a790-4e5b-b89a-4a814917b94e
# 15  6216e565-a790-4e5b-b89a-4a814917b94e
# 16  6216e565-a790-4e5b-b89a-4a814917b94e
# 17  6216e565-a790-4e5b-b89a-4a814917b94e
# 18  6216e565-a790-4e5b-b89a-4a814917b94e
# 19  6216e565-a790-4e5b-b89a-4a814917b94e
# 20  6216e565-a790-4e5b-b89a-4a814917b94e
# 21  6216e565-a790-4e5b-b89a-4a814917b94e
# 22  6216e565-a790-4e5b-b89a-4a814917b94e
# 23  6216e565-a790-4e5b-b89a-4a814917b94e
# 24  6216e565-a790-4e5b-b89a-4a814917b94e
# 25  6216e565-a790-4e5b-b89a-4a814917b94e
# 26  6216e565-a790-4e5b-b89a-4a814917b94e
# 27  6216e565-a790-4e5b-b89a-4a814917b94e
# 28  6216e565-a790-4e5b-b89a-4a814917b94e
# 29  6216e565-a790-4e5b-b89a-4a814917b94e
# 30  6216e565-a790-4e5b-b89a-4a814917b94e
# 31  6216e565-a790-4e5b-b89a-4a814917b94e
# 32  6216e565-a790-4e5b-b89a-4a814917b94e
# 33  6216e565-a790-4e5b-b89a-4a814917b94e
# 34  6216e565-a790-4e5b-b89a-4a814917b94e
# 35  6216e565-a790-4e5b-b89a-4a814917b94e
#
#                                  deck_name deck_wins deck_losses  \
# 0   Leif “As”, Granjera de la Alcantarilla         2           1
# 1   Leif “As”, Granjera de la Alcantarilla         2           1
# 2   Leif “As”, Granjera de la Alcantarilla         2           1
# 3   Leif “As”, Granjera de la Alcantarilla         2           1
# 4   Leif “As”, Granjera de la Alcantarilla         2           1
# 5   Leif “As”, Granjera de la Alcantarilla         2           1
# 6   Leif “As”, Granjera de la Alcantarilla         2           1
# 7   Leif “As”, Granjera de la Alcantarilla         2           1
# 8   Leif “As”, Granjera de la Alcantarilla         2           1
# 9   Leif “As”, Granjera de la Alcantarilla         2           1
# 10  Leif “As”, Granjera de la Alcantarilla         2           1
# 11  Leif “As”, Granjera de la Alcantarilla         2           1
# 12  Leif “As”, Granjera de la Alcantarilla         2           1
# 13  Leif “As”, Granjera de la Alcantarilla         2           1
# 14  Leif “As”, Granjera de la Alcantarilla         2           1
# 15  Leif “As”, Granjera de la Alcantarilla         2           1
# 16  Leif “As”, Granjera de la Alcantarilla         2           1
# 17  Leif “As”, Granjera de la Alcantarilla         2           1
# 18  Leif “As”, Granjera de la Alcantarilla         2           1
# 19  Leif “As”, Granjera de la Alcantarilla         2           1
# 20  Leif “As”, Granjera de la Alcantarilla         2           1
# 21  Leif “As”, Granjera de la Alcantarilla         2           1
# 22  Leif “As”, Granjera de la Alcantarilla         2           1
# 23  Leif “As”, Granjera de la Alcantarilla         2           1
# 24  Leif “As”, Granjera de la Alcantarilla         2           1
# 25  Leif “As”, Granjera de la Alcantarilla         2           1
# 26  Leif “As”, Granjera de la Alcantarilla         2           1
# 27  Leif “As”, Granjera de la Alcantarilla         2           1
# 28  Leif “As”, Granjera de la Alcantarilla         2           1
# 29  Leif “As”, Granjera de la Alcantarilla         2           1
# 30  Leif “As”, Granjera de la Alcantarilla         2           1
# 31  Leif “As”, Granjera de la Alcantarilla         2           1
# 32  Leif “As”, Granjera de la Alcantarilla         2           1
# 33  Leif “As”, Granjera de la Alcantarilla         2           1
# 34  Leif “As”, Granjera de la Alcantarilla         2           1
# 35  Leif “As”, Granjera de la Alcantarilla         2           1
#
#    deck_expansion               card_name
# 0             435             Drummernaut
# 1             435             Drummernaut
# 2             435             First Blood
# 3             435        Ganger Chieftain
# 4             435        Ganger Chieftain
# 5             435                Groggins
# 6             435                   Groke
# 7             435                   Groke
# 8             435           Into the Fray
# 9             435      Lollop the Titanic
# 10            435                  Tremor
# 11            435              Barehanded
# 12            435    Abond the Armorsmith
# 13            435          Blinding Light
# 14            435     Bordan the Redeemed
# 15            435    Challe the Safeguard
# 16            435             Sir Marrows
# 17            435                   Smite
# 18            435           Take Hostages
# 19            435          The Grey Rider
# 20            435          The Grey Rider
# 21            435         Haedroth’s Wall
# 22            435  Prince Derric, Unifier
# 23            435         The Vaultkeeper
# 24            435               Duskwitch
# 25            435             Grovekeeper
# 26            435              Key Charge
# 27            435                Regrowth
# 28            435              Rustgnawer
# 29            435               Tantadlin
# 30            435     They’re Everywhere!
# 31            435          Grasping Vines
# 32            435          Grasping Vines
# 33            435           Panpaca, Anga
# 34            435           Panpaca, Anga
# 35            435               Quicksand
